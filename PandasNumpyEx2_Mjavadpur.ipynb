# %% [markdown]
# <a href="https://colab.research.google.com/github/mjavadpur/PandasNumpy/blob/main/PandasNumpyEx2_Mjavadpur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mohammad Javadpur - Pandas & Numpy Workshop Task2**

# %% [markdown]
# ### **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Setting *Environment* Variables**

# %%
import os 
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Workshop/PandasNumpy/Session2'
os.environ['KAGGLE_USERNAME'] = "mjavadpur" # username from the json file
os.environ['KAGGLE_KEY'] = "3e9baf1e03d7cb7e8976be19949d267a" # key from the json file

# %% [markdown]
# ### **Change Current Directory**

# %%
# %cd /content/drive/MyDrive/Workshop/PandasNumpy/Session2
# Out:
# /content/drive/MyDrive/Workshop/PandasNumpy/Session2

# %% [markdown]
# # **Download Dataset in Google Drive**

# %%
# !kaggle datasets download -d iabhishekofficial/mobile-price-classification
# Out:
# ...
#   0% 0.00/70.6k [00:00<?, ?B/s]
# 100% 70.6k/70.6k [00:00<00:00, 10.4MB/s]

# %% [markdown]
# # **Unzip Data**

# %%
# %%capture
# !unzip /content/drive/MyDrive/Workshop/PandasNumpy/Session2/mobile-price-classification.zip -d /content/drive/MyDrive/Workshop/PandasNumpy/Session2
# Out:
# Archive:  /content/drive/MyDrive/Workshop/PandasNumpy/Session2/mobile-price-classification.zip
#   inflating: /content/drive/MyDrive/Workshop/PandasNumpy/Session2/test.csv
#   inflating: /content/drive/MyDrive/Workshop/PandasNumpy/Session2/train.csv

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Import dataset**

# %%
df = pd.read_csv('train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.read_csv('train.csv',index_col = 1)
# Out:
#       battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# blue
# 0               842          2.2         0   1       0           7    0.6
# 1              1021          0.5         1   0       1          53    0.7
# 1               563          0.5         1   2       1          41    0.9
# 1               615          2.5         0   0       0          10    0.8
# 1              1821          1.2         0  13       1          44    0.6
# ...             ...          ...       ...  ..     ...         ...    ...
# 1               794          0.5         1   0       1           2    0.8
# 1              1965          2.6         1   0       0          39    0.2
# 0              1911          0.9         1   1       1          36    0.7
# 0              1512          0.9         0   4       1          46    0.1
# 1               510          2.0         1   5       1          45    0.9
#
#       mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.read_csv('train.csv',index_col = ('price_range','int_memory'))
# Out:
#                         battery_power  blue  clock_speed  dual_sim  fc  \
# price_range int_memory
# 1           7                     842     0          2.2         0   1
# 2           53                   1021     1          0.5         1   0
#             41                    563     1          0.5         1   2
#             10                    615     1          2.5         0   0
# 1           44                   1821     1          1.2         0  13
# ...                               ...   ...          ...       ...  ..
# 0           2                     794     1          0.5         1   0
# 2           39                   1965     1          2.6         1   0
# 3           36                   1911     0          0.9         1   1
# 0           46                   1512     0          0.9         0   4
# 3           45                    510     1          2.0         1   5
#
#                         four_g  m_dep  mobile_wt  n_cores  pc  px_height  \
# ...

# %%
df.iloc[2:10, 2:5]
# Out:
#    clock_speed  dual_sim  fc
# 2          0.5         1   2
# 3          2.5         0   0
# 4          1.2         0  13
# 5          0.5         1   3
# 6          1.7         0   4
# 7          0.5         1   0
# 8          0.5         0   0
# 9          0.6         1   2

# %%
df.iloc[:2, 5:]
# Out:
#    four_g  int_memory  m_dep  mobile_wt  n_cores  pc  px_height  px_width  \
# 0       0           7    0.6        188        2   2         20       756
# 1       1          53    0.7        136        3   6        905      1988
#
#     ram  sc_h  sc_w  talk_time  three_g  touch_screen  wifi  price_range
# 0  2549     9     7         19        0             0     1            1
# 1  2631    17     3          7        1             1     0            2

# %%
df.loc[:, ("int_memory", "price_range")]
# Out:
#       int_memory  price_range
# 0              7            1
# 1             53            2
# 2             41            2
# 3             10            2
# 4             44            1
# ...          ...          ...
# 1995           2            0
# 1996          39            2
# 1997          36            3
# 1998          46            0
# 1999          45            3
#
# [2000 rows x 2 columns]

# %%
df.loc[12:30, ("int_memory", "price_range")]
# Out:
#     int_memory  price_range
# 12          33            1
# 13          17            2
# 14          52            0
# 15          46            0
# 16          13            3
# 17          23            3
# 18          49            1
# 19          19            1
# 20          39            3
# 21          13            3
# 22          47            1
# 23          38            0
# 24           8            1
# 25          57            2
# 26          51            3
# 27          41            3
# 28          52            2
# 29          21            0
# 30           5            3

# %%
pd.read_csv('train.csv',index_col = 1, header=None)
# Out:
#                  0            2         3   4       5           6      7   \
# 1
# blue  battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep
# 0               842          2.2         0   1       0           7    0.6
# 1              1021          0.5         1   0       1          53    0.7
# 1               563          0.5         1   2       1          41    0.9
# 1               615          2.5         0   0       0          10    0.8
# ...             ...          ...       ...  ..     ...         ...    ...
# 1               794          0.5         1   0       1           2    0.8
# 1              1965          2.6         1   0       0          39    0.2
# 0              1911          0.9         1   1       1          36    0.7
# 0              1512          0.9         0   4       1          46    0.1
# 1               510          2.0         1   5       1          45    0.9
#
#              8        9   10         11        12    13    14    15  \
# 1
# ...

# %%
pd.read_csv('train.csv',index_col = 1, header=55)
# Out:
#     1073  0.5  1.1   0  0.1  51  0.5.1  145  7  0.2   690   804  2908   6  \
# 1
# 0   1936  2.1    1  10    1  46    0.6  104  3   20   667  1036  2552  14
# 1    823  2.7    1  13    0  60    0.5  148  8   19   822  1449   905  14
# 0    987  1.3    1   0    1  61    0.4  107  3    9   581   820  3963   9
# 0   1757  0.5    0   8    0  49    0.5  180  6   14   265   713  2056   7
# 0   1063  1.4    1   2    1  48    1.0  128  5    4   127   683  2910  15
# ..   ...  ...  ...  ..  ...  ..    ...  ... ..  ...   ...   ...   ...  ..
# 1    794  0.5    1   0    1   2    0.8  106  6   14  1222  1890   668  13
# 1   1965  2.6    1   0    0  39    0.2  187  4    3   915  1965  2032  11
# 0   1911  0.9    1   1    1  36    0.7  108  8    3   868  1632  3057   9
# 0   1512  0.9    0   4    1  46    0.1  145  5    5   336   670   869  18
# 1    510  2.0    1   5    1  45    0.9  168  6   16   483   754  3919  19
#
#     0.3  18  0.4  1.2  0.6  2
# 1
# 0     7  13    1    0    0  2
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
df.values
# Out:
# array([[8.420e+02, 0.000e+00, 2.200e+00, ..., 0.000e+00, 1.000e+00,
#         1.000e+00],
#        [1.021e+03, 1.000e+00, 5.000e-01, ..., 1.000e+00, 0.000e+00,
#         2.000e+00],
#        [5.630e+02, 1.000e+00, 5.000e-01, ..., 1.000e+00, 0.000e+00,
#         2.000e+00],
#        ...,
#        [1.911e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 0.000e+00,
#         3.000e+00],
#        [1.512e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [5.100e+02, 1.000e+00, 2.000e+00, ..., 1.000e+00, 1.000e+00,
#         3.000e+00]])

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
#
# [3 rows x 21 columns]

# %%
df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# # **Get some information about dataset**

# %%
df.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.count()
# Out:
# battery_power    2000
# blue             2000
# clock_speed      2000
# dual_sim         2000
# fc               2000
# four_g           2000
# int_memory       2000
# m_dep            2000
# mobile_wt        2000
# n_cores          2000
# pc               2000
# px_height        2000
# px_width         2000
# ram              2000
# sc_h             2000
# sc_w             2000
# talk_time        2000
# three_g          2000
# touch_screen     2000
# wifi             2000
# price_range      2000
# dtype: int64

# %%
df['int_memory'].value_counts()
# Out:
# 27    47
# 16    45
# 14    45
# 57    42
# 2     42
#       ..
# 22    24
# 38    23
# 62    21
# 4     20
# 59    18
# Name: int_memory, Length: 63, dtype: int64

# %%
df['int_memory'].unique()
# Out:
# array([ 7, 53, 41, 10, 44, 22, 24,  9, 33, 17, 52, 46, 13, 23, 49, 19, 39,
#        47, 38,  8, 57, 51, 21,  5, 60, 61,  6, 11, 50, 34, 20, 27, 42, 40,
#        64, 14, 63, 43, 16, 48, 12, 55, 36, 30, 45, 29, 58, 25,  3, 54, 15,
#        37, 31, 32,  4, 18,  2, 56, 26, 35, 59, 28, 62])

# %%
df['int_memory'].mean()
# Out:
# 32.0465

# %%
df[['int_memory', 'sc_w']]
# Out:
#       int_memory  sc_w
# 0              7     7
# 1             53     3
# 2             41     2
# 3             10     8
# 4             44     2
# ...          ...   ...
# 1995           2     4
# 1996          39    10
# 1997          36     1
# 1998          46    10
# 1999          45     4
#
# [2000 rows x 2 columns]

# %%
df[['int_memory', 'sc_w']].mean()
# Out:
# int_memory    32.0465
# sc_w           5.7670
# dtype: float64

# %%
df[['int_memory', 'sc_w']].mean(axis = 1)
# Out:
# 0        7.0
# 1       28.0
# 2       21.5
# 3        9.0
# 4       23.0
#         ...
# 1995     3.0
# 1996    24.5
# 1997    18.5
# 1998    28.0
# 1999    24.5
# Length: 2000, dtype: float64

# %%
print(df['talk_time'].sum())
print(df['talk_time'].max())
print(df['talk_time'].min())
print(df['talk_time'].std())
# Out:
# 22022
# 20
# 2
# 5.463955197766688

# %%
df_copy = df.copy()

# %%
plt.hist(df['talk_time'],orientation='vertical')
# Out:
# (array([193., 216., 235., 204., 105., 202., 201., 231., 198., 215.]),
#  array([ 2. ,  3.8,  5.6,  7.4,  9.2, 11. , 12.8, 14.6, 16.4, 18.2, 20. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['talk_time'],orientation='horizontal')
# Out:
# (array([193., 216., 235., 204., 105., 202., 201., 231., 198., 215.]),
#  array([ 2. ,  3.8,  5.6,  7.4,  9.2, 11. , 12.8, 14.6, 16.4, 18.2, 20. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=df,x="talk_time",kde=True,hue='price_range')
# Out:
# <Axes: xlabel='talk_time', ylabel='Count'>

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
sns.kdeplot(data=df[['n_cores','fc']])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(data=df[['n_cores','fc']],kde=True)

# %%
df[['n_cores','fc']].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df[['n_cores','fc']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['mobile_wt', 'n_cores', 'px_height',
       'px_width', 'ram', 'sc_h']].plot(kind='hist', subplots= True,layout=(2,3),sharex= False)
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>]], dtype=object)

# %%
plt.scatter(data=df,x="ram",y="n_cores")

# %%
sns.scatterplot(data=df,x="ram",y="n_cores",hue='price_range')
# Out:
# <Axes: xlabel='ram', ylabel='n_cores'>

# %% [markdown]
# # **Correlation Report with heatmap visualization**

# %%
df = pd.read_csv('train.csv')

# %%
sns.lmplot(data=df,x="n_cores",y="fc")

# %%
sns.jointplot(data=df,x="n_cores",y="fc")

# %% [markdown]
# # **Scatter Report**

# %%
pd.plotting.scatter_matrix(df, figsize=(25,15), alpha=0.5)
plt.show()

# %% [markdown]
# # **Split Label 'price_range' of data**

# %%
y.unique()
# Out:
# array([0, 1])

# %%
df.hist(bins=10, 
        figsize=(20,40),
        layout=(15,4));

# %%
df.drop_duplicates()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.isnull().sum() 
df.isnull().sum().sum()
# Out:
# 0

# %%
plt.scatter(df['battery_power'], df['mobile_wt'], marker ="*", edgecolor ="black", s = 200, alpha=0.3)
plt.show()

# %%
plt.scatter(df['battery_power'], df['mobile_wt'], marker ="*", edgecolor ="black", s = 150, linewidths = 2)

# %%
sns.jointplot(data=df, x="battery_power", y="mobile_wt", hue="price_range")
