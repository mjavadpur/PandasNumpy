# %% [markdown]
# <a href="https://colab.research.google.com/github/mjavadpur/PandasNumpy/blob/main/PandasNumpyEx1_Mjavadpur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mohammad Javadpur - Pandas & Numpy Workshop Task**

# %% [markdown]
# ### **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Setting *Environment* Variables**

# %%
import os 
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Workshop/PandasNumpy'
os.environ['KAGGLE_USERNAME'] = "mjavadpur" # username from the json file
os.environ['KAGGLE_KEY'] = "3e9baf1e03d7cb7e8976be19949d267a" # key from the json file

# %% [markdown]
# ### **Change Current Directory**

# %%
# %cd /content/drive/MyDrive/Workshop/PandasNumpy
# Out:
# /content/drive/MyDrive/Workshop/PandasNumpy

# %% [markdown]
# # **Download Dataset in Google Drive**

# %%
# !kaggle datasets download -d dileep070/heart-disease-prediction-using-logistic-regression
# Out:
# ...
#   0% 0.00/58.4k [00:00<?, ?B/s]
# 100% 58.4k/58.4k [00:00<00:00, 10.6MB/s]

# %% [markdown]
# # **Unzip Data**

# %%
# %%capture
# !unzip /content/drive/MyDrive/Workshop/PandasNumpy/heart-disease-prediction-using-logistic-regression.zip -d /content/drive/MyDrive/Workshop/PandasNumpy
# Out:
# Archive:  /content/drive/MyDrive/Workshop/PandasNumpy/heart-disease-prediction-using-logistic-regression.zip
#   inflating: /content/drive/MyDrive/Workshop/PandasNumpy/framingham.csv

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Import dataset**

# %%
df = pd.read_csv('framingham.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
pd.read_csv('framingham.csv',index_col = 1)
# Out:
#      male  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# age
# 39      1        4.0              0         0.0     0.0                0
# 46      0        2.0              0         0.0     0.0                0
# 48      1        1.0              1        20.0     0.0                0
# 61      0        3.0              1        30.0     0.0                0
# 46      0        3.0              1        23.0     0.0                0
# ..    ...        ...            ...         ...     ...              ...
# 50      1        1.0              1         1.0     0.0                0
# 51      1        3.0              1        43.0     0.0                0
# 48      0        2.0              1        20.0     NaN                0
# 44      0        1.0              1        15.0     0.0                0
# 52      0        2.0              0         0.0     0.0                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# age
# ...

# %%
pd.read_csv('framingham.csv',index_col = 'education')
# Out:
#            male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# education
# 4.0           1   39              0         0.0     0.0                0
# 2.0           0   46              0         0.0     0.0                0
# 1.0           1   48              1        20.0     0.0                0
# 3.0           0   61              1        30.0     0.0                0
# 3.0           0   46              1        23.0     0.0                0
# ...         ...  ...            ...         ...     ...              ...
# 1.0           1   50              1         1.0     0.0                0
# 3.0           1   51              1        43.0     0.0                0
# 2.0           0   48              1        20.0     NaN                0
# 1.0           0   44              1        15.0     0.0                0
# 2.0           0   52              0         0.0     0.0                0
#
#            prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
pd.read_csv('framingham.csv',index_col = ('education','totChol'))
# Out:
#                    male  age  currentSmoker  cigsPerDay  BPMeds  \
# education totChol
# 4.0       195.0       1   39              0         0.0     0.0
# 2.0       250.0       0   46              0         0.0     0.0
# 1.0       245.0       1   48              1        20.0     0.0
# 3.0       225.0       0   61              1        30.0     0.0
#           285.0       0   46              1        23.0     0.0
# ...                 ...  ...            ...         ...     ...
# 1.0       313.0       1   50              1         1.0     0.0
# 3.0       207.0       1   51              1        43.0     0.0
# 2.0       248.0       0   48              1        20.0     NaN
# 1.0       210.0       0   44              1        15.0     0.0
# 2.0       269.0       0   52              0         0.0     0.0
#
#                    prevalentStroke  prevalentHyp  diabetes  sysBP  diaBP  \
# education totChol
# 4.0       195.0                  0             0         0  106.0   70.0
# ...

# %%
df.iloc[2:10, 2:5]
# Out:
#    education  currentSmoker  cigsPerDay
# 2        1.0              1        20.0
# 3        3.0              1        30.0
# 4        3.0              1        23.0
# 5        2.0              0         0.0
# 6        1.0              0         0.0
# 7        2.0              1        20.0
# 8        1.0              0         0.0
# 9        1.0              1        30.0

# %%
df.iloc[:2, 5:]
# Out:
#    BPMeds  prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP  \
# 0     0.0                0             0         0    195.0  106.0   70.0
# 1     0.0                0             0         0    250.0  121.0   81.0
#
#      BMI  heartRate  glucose
# 0  26.97       80.0     77.0
# 1  28.73       95.0     76.0

# %%
df.loc[:, ("totChol", "sysBP")]
# Out:
#       totChol  sysBP
# 0       195.0  106.0
# 1       250.0  121.0
# 2       245.0  127.5
# 3       225.0  150.0
# 4       285.0  130.0
# ...       ...    ...
# 4233    313.0  179.0
# 4234    207.0  126.5
# 4235    248.0  131.0
# 4236    210.0  126.5
# 4237    269.0  133.5
#
# [4238 rows x 2 columns]

# %%
df.loc[12:30, ("diaBP", "heartRate")]
# Out:
#     diaBP  heartRate
# 12   94.0       98.0
# 13   88.0       65.0
# 14   64.0       85.0
# 15   90.0       95.0
# 16   90.0       64.0
# 17   78.0       80.0
# 18   84.5       75.0
# 19   88.0       85.0
# 20   70.5       72.0
# 21   77.5       70.0
# 22   78.0       70.0
# 23   82.0       71.0
# 24   90.0       75.0
# 25   68.0       62.0
# 26   72.5       65.0
# 27   91.0       73.0
# 28  121.0       85.0
# 29   88.0       72.0
# 30   68.0       60.0

# %%
df = pd.read_csv('framingham.csv',index_col = 'TenYearCHD')
df.loc[1, ("diaBP", "heartRate")]
# Out:
#             diaBP  heartRate
# TenYearCHD
# 1            95.0       65.0
# 1            71.0       60.0
# 1            90.0       95.0
# 1            78.0       80.0
# 1            68.0       62.0
# ...           ...        ...
# 1            74.0       80.0
# 1            98.0       90.0
# 1            84.0       67.0
# 1            97.0       60.0
# 1            92.0       66.0
#
# [644 rows x 2 columns]

# %%
pd.read_csv('framingham.csv',index_col = 1, header=None)
# Out:
#        0          2              3           4       5                6   \
# 1
# age  male  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke
# 39      1          4              0           0       0                0
# 46      0          2              0           0       0                0
# 48      1          1              1          20       0                0
# 61      0          3              1          30       0                0
# ..    ...        ...            ...         ...     ...              ...
# 50      1          1              1           1       0                0
# 51      1          3              1          43       0                0
# 48      0          2              1          20     NaN                0
# 44      0          1              1          15       0                0
# 52      0          2              0           0       0                0
#
#                7         8        9      10     11     12         13       14  \
# 1
# ...

# %%
pd.read_csv('framingham.csv',index_col = 1, header=55)
# Out:
#     0    2  1    20  0.1  0.2  0.3  0.4    209    115     75  22.54    90  \
# 39
# 46  0  1.0  1  10.0  0.0    0    0    0  250.0  116.0   71.0  20.35  88.0
# 54  0  1.0  1   9.0  0.0    0    0    1  266.0  114.0   76.0  17.61  88.0
# 49  1  1.0  1   2.0  0.0    0    1    0  255.0  143.5   81.0  25.65  75.0
# 44  1  2.0  0   0.0  0.0    0    0    0  185.0  115.0   69.0  22.29  65.0
# 40  0  4.0  1  20.0  0.0    0    0    0  205.0  158.0  102.0  25.45  75.0
# .. ..  ... ..   ...  ...  ...  ...  ...    ...    ...    ...    ...   ...
# 50  1  1.0  1   1.0  0.0    0    1    0  313.0  179.0   92.0  25.97  66.0
# 51  1  3.0  1  43.0  0.0    0    0    0  207.0  126.5   80.0  19.71  65.0
# 48  0  2.0  1  20.0  NaN    0    0    0  248.0  131.0   72.0  22.00  84.0
# 44  0  1.0  1  15.0  0.0    0    0    0  210.0  126.5   87.0  19.16  86.0
# 52  0  2.0  0   0.0  0.0    0    0    0  269.0  133.5   83.0  21.47  80.0
#
#        NA  0.5
# 39
# 46   94.0    0
# 54   55.0    0
# 49   80.0    0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4238, step=1)

# %%
df.values
# Out:
# array([[  1.  ,  39.  ,   4.  , ...,  26.97,  80.  ,  77.  ],
#        [  0.  ,  46.  ,   2.  , ...,  28.73,  95.  ,  76.  ],
#        [  1.  ,  48.  ,   1.  , ...,  25.34,  75.  ,  70.  ],
#        ...,
#        [  0.  ,  48.  ,   2.  , ...,  22.  ,  84.  ,  86.  ],
#        [  0.  ,  44.  ,   1.  , ...,  19.16,  86.  ,    nan],
#        [  0.  ,  52.  ,   2.  , ...,  21.47,  80.  , 107.  ]])

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose'],
#       dtype='object')

# %%
df.head(3)
# Out:
#             male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# TenYearCHD
# 0              1   39        4.0              0         0.0     0.0
# 0              0   46        2.0              0         0.0     0.0
# 0              1   48        1.0              1        20.0     0.0
#
#             prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP  \
# TenYearCHD
# 0                         0             0         0    195.0  106.0   70.0
# 0                         0             0         0    250.0  121.0   81.0
# 0                         0             0         0    245.0  127.5   80.0
#
#               BMI  heartRate  glucose
# TenYearCHD
# 0           26.97       80.0     77.0
# 0           28.73       95.0     76.0
# 0           25.34       75.0     70.0

# %%
df.tail()
# Out:
#             male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# TenYearCHD
# 1              1   50        1.0              1         1.0     0.0
# 0              1   51        3.0              1        43.0     0.0
# 0              0   48        2.0              1        20.0     NaN
# 0              0   44        1.0              1        15.0     0.0
# 0              0   52        2.0              0         0.0     0.0
#
#             prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP  \
# TenYearCHD
# 1                         0             1         0    313.0  179.0   92.0
# 0                         0             0         0    207.0  126.5   80.0
# 0                         0             0         0    248.0  131.0   72.0
# 0                         0             0         0    210.0  126.5   87.0
# 0                         0             0         0    269.0  133.5   83.0
#
#               BMI  heartRate  glucose
# TenYearCHD
# ...

# %% [markdown]
# # **Get some information about dataset**

# %%
df.describe().T
# Out:
#                   count        mean        std     min     25%    50%  \
# male             4238.0    0.429212   0.495022    0.00    0.00    0.0
# age              4238.0   49.584946   8.572160   32.00   42.00   49.0
# education        4133.0    1.978950   1.019791    1.00    1.00    2.0
# currentSmoker    4238.0    0.494101   0.500024    0.00    0.00    0.0
# cigsPerDay       4209.0    9.003089  11.920094    0.00    0.00    0.0
# BPMeds           4185.0    0.029630   0.169584    0.00    0.00    0.0
# prevalentStroke  4238.0    0.005899   0.076587    0.00    0.00    0.0
# prevalentHyp     4238.0    0.310524   0.462763    0.00    0.00    0.0
# diabetes         4238.0    0.025720   0.158316    0.00    0.00    0.0
# totChol          4188.0  236.721585  44.590334  107.00  206.00  234.0
# sysBP            4238.0  132.352407  22.038097   83.50  117.00  128.0
# diaBP            4238.0   82.893464  11.910850   48.00   75.00   82.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.count()
# Out:
# male               4238
# age                4238
# education          4133
# currentSmoker      4238
# cigsPerDay         4209
# BPMeds             4185
# prevalentStroke    4238
# prevalentHyp       4238
# diabetes           4238
# totChol            4188
# sysBP              4238
# diaBP              4238
# BMI                4219
# heartRate          4237
# glucose            3850
# dtype: int64

# %%
df['age'].value_counts()
# Out:
# 40    191
# 46    182
# 42    180
# 41    174
# 48    173
# 39    169
# 44    166
# 45    162
# 43    159
# 52    149
# 51    146
# 55    145
# 38    144
# 47    141
# 50    140
# 53    139
# 54    132
# 49    132
# 57    123
# 56    123
# 59    119
# 58    117
# 60    111
# 63    110
# 61    110
# 62     99
# 64     93
# 37     92
# 36     84
# 65     57
# 67     45
# 35     42
# 66     38
# 34     18
# 68     18
# 69      7
# 33      5
# 70      2
# 32      1
# Name: age, dtype: int64

# %%
df['diaBP'].unique()
# Out:
# array([ 70. ,  81. ,  80. ,  95. ,  84. , 110. ,  71. ,  89. , 107. ,
#         76. ,  88. ,  94. ,  64. ,  90. ,  78. ,  84.5,  70.5,  77.5,
#         82. ,  68. ,  72.5,  91. , 121. ,  85.5,  85. ,  82.5,  74. ,
#         92.5, 102. ,  98. , 101. ,  73. ,  92. ,  83.5,  63. , 114. ,
#         69. ,  93. ,  66. ,  75. ,  79. ,  87. ,  99. ,  60. ,  67.5,
#        106. ,  86.5, 104. ,  86. ,  61.5,  71.5,  76.5,  77. ,  88.5,
#        105. ,  96. ,  97. , 100. ,  81.5, 106.5,  80.5, 124.5,  61. ,
#         83. ,  67. ,  74.5,  66.5,  65. ,  72. ,  99.5, 122.5,  57. ,
#         57.5, 111. ,  78.5, 104.5,  89.5, 112. ,  55. , 123. , 120. ,
#         75.5, 118. ,  97.5,  59. , 133. ,  69.5,  95.5,  96.5, 135. ,
#         64.5,  68.5,  98.5,  62. , 117. ,  59.5, 103. , 108.5,  73.5,
#         87.5, 108. ,  93.5,  90.5, 114.5,  62.5,  94.5, 140. , 124. ,
#         79.5, 109. ,  91.5, 115. , 102.5,  65.5, 105.5, 103.5,  63.5,
# ...

# %%
df['diaBP'].mean()
# Out:
# 82.89346389806512

# %%
df[['age', 'diaBP']]
# Out:
#             age  diaBP
# TenYearCHD
# 0            39   70.0
# 0            46   81.0
# 0            48   80.0
# 1            61   95.0
# 0            46   84.0
# ...         ...    ...
# 1            50   92.0
# 0            51   80.0
# 0            48   72.0
# 0            44   87.0
# 0            52   83.0
#
# [4238 rows x 2 columns]

# %%
df[['age', 'diaBP']].mean()
# Out:
# age      49.584946
# diaBP    82.893464
# dtype: float64

# %%
df[['age', 'diaBP']].mean(axis = 1)
# Out:
# TenYearCHD
# 0    54.5
# 0    63.5
# 0    64.0
# 1    78.0
# 0    65.0
#      ...
# 1    71.0
# 0    65.5
# 0    60.0
# 0    65.5
# 0    67.5
# Length: 4238, dtype: float64

# %%
print(df['diaBP'].sum())
print(df['diaBP'].max())
print(df['diaBP'].min())
print(df['diaBP'].std())
# Out:
# 351302.5
# 142.5
# 48.0
# 11.9108496002255

# %%
df_copy = df.copy()

# %%
plt.hist(df['age'],orientation='vertical')
# Out:
# (array([ 66., 489., 704., 651., 445., 566., 508., 439., 298.,  72.]),
#  array([32. , 35.8, 39.6, 43.4, 47.2, 51. , 54.8, 58.6, 62.4, 66.2, 70. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['age'],orientation='horizontal')
# Out:
# (array([ 66., 489., 704., 651., 445., 566., 508., 439., 298.,  72.]),
#  array([32. , 35.8, 39.6, 43.4, 47.2, 51. , 54.8, 58.6, 62.4, 66.2, 70. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=df,x="age",kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(data=df[['age','diaBP']])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(data=df[['age','diaBP']],kde=True)

# %%
df[['age','diaBP']].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df[['age','diaBP']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['age',  'currentSmoker', 'cigsPerDay', 'BPMeds']].plot(kind='hist', subplots= True,layout=(2,2),sharex= False)
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>]],
#       dtype=object)

# %%
plt.scatter(data=df,x="age",y="diaBP")

# %%
sns.scatterplot(data=df,x="age",y="diaBP",hue="TenYearCHD")
# Out:
# <Axes: xlabel='age', ylabel='diaBP'>

# %% [markdown]
# # **Correlation Report with heatmap visualization**

# %%
df = pd.read_csv('framingham.csv',index_col = 'TenYearCHD')

# %%
sns.lmplot(data=df,x="age",y="diaBP")

# %%
sns.lmplot(x="diaBP", y='cigsPerDay',hue="TenYearCHD", data=df)

# %%
sns.jointplot(data=df,x="age",y="diaBP")

# %% [markdown]
# # **Scatter Report**

# %%
pd.plotting.scatter_matrix(df, figsize=(25,15), alpha=0.5)
plt.show()

# %% [markdown]
# # **Split Label 'BodyFat' of data**

# %%
y = df.pop('TenYearCHD')

X = df

print(f'Shape of label is {np.shape(y)}')
print(f'Shape of Data is {np.shape(X)}')
# Out:
# Shape of label is (4238,)
# Shape of Data is (4238, 15)

# %%
y.unique()
# Out:
# array([0, 1])

# %%
df.hist(bins=10, 
        figsize=(20,40),
        layout=(15,4));

# %%
#all-columns list
df_all_colum=list(df.columns)

# discrete/categorical column list
discrete_cols=['male', 'currentSmoker', 'prevalentStroke', 'prevalentHyp', 'diabetes', 'education', 'BPMeds']

#continuous column list
continuous_cols=['age', 'cigsPerDay', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose']

# %%
df[continuous_cols].hist(bins=30, 
        figsize=(20,40),
        layout=(15,4));

# %%
df.drop_duplicates()

# %%
df.isnull().sum() 
df.isnull().sum().sum()
# Out:
# 645

# %%
plt.scatter(df['totChol'], df['sysBP'], marker ="*", edgecolor ="black", s = 200, alpha=0.3)
plt.show()

# %%
plt.scatter(df['totChol'], df['diaBP'], marker ="*", edgecolor ="black", s = 150, linewidths = 2)
